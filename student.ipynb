# %% [markdown]
# <a href="https://colab.research.google.com/github/thenmozhithenmozhi442-byte/Student-Performance-Result-Analytics/blob/main/student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("students.csv")
df["Average"] = df[["Maths", "Science", "English"]].mean(axis=1)
def grade(avg):
    if avg >= 90:
        return "A+"
    elif avg >= 80:
        return "A"
    elif avg >= 70:
        return "B"
    elif avg >= 60:
        return "C"
    elif avg >= 50:
        return "D"
    else:
        return "F"
df["Grade"] = df["Average"].apply(grade)
def status(row):
    if row["Maths"] >= 40 and row["Science"] >= 40 and row["English"] >= 40:
        return "Pass"
    else:
        return "Fail"
df["Status"] = df.apply(status, axis=1)
print("\nStudent Result Analysis")
print(df)
topper = df.loc[df["Average"].idxmax()]
print("\nTopper Details:")
print(topper)
weak_students = df[df["Average"] < 50]
print("\nWeak Students:")
print(weak_students[["Name", "Average"]])
subject_avg = df[["Maths", "Science", "English"]].mean()
print("\nSubject Wise Average Marks:")
print(subject_avg)
class_average = df["Average"].mean()
print("\nOverall Class Average:", round(class_average, 2))
plt.figure(figsize=(6,4))
subject_avg.plot(kind='bar', color=['blue','green','orange'])
plt.title("Subject Wise Average Marks")
plt.ylabel("Average Marks")
plt.show()
status_count = df["Status"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(status_count,
        labels=status_count.index,
        autopct='%1.1f%%',
        colors=['lightgreen','red'])
plt.title("Pass vs Fail Students")
plt.show()
plt.figure(figsize=(8,4))
plt.bar(df["Name"], df["Average"], color='purple')
plt.title("Student Average Marks")
plt.xlabel("Students")
plt.ylabel("Average")
plt.xticks(rotation=45)
plt.show()
# Out:
# Student Result Analysis
#      Name  Maths  Science  English    Average Grade Status
# 0    Arun     95       88       90  91.000000    A+   Pass
# 1    Bala     45       50       40  45.000000     F   Pass
# 2  Charan     78       82       75  78.333333     B   Pass
# 3   Divya     92       96       94  94.000000    A+   Pass
# 4    Esha     35       42       38  38.333333     F   Fail
# 5  Farhan     65       70       68  67.666667     C   Pass
# 6   Gokul     85       80       88  84.333333     A   Pass
# 7  Harini     55       60       58  57.666667     D   Pass
#
# Topper Details:
# Name       Divya
# Maths         92
# Science       96
# English       94
# Average     94.0
# Grade         A+
# Status      Pass
# Name: 3, dtype: object
#
# Weak Students:
#    Name    Average
# 1  Bala  45.000000
# 4  Esha  38.333333
#
# Subject Wise Average Marks:
# Maths      68.750
# Science    71.000
# English    68.875
# dtype: float64
#
# Overall Class Average: 69.54
